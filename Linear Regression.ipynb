# %%
import pandas as pd
import numpy as np

# %%
file=r'/Users/lalitsachan/Dropbox/PDS V3/Data/loans data.csv'

ld=pd.read_csv(file)

ld
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-6ffbc7dbdbf9> in <module>()
#       1 file=r'/Users/lalitsachan/Dropbox/PDS V3/Data/loans data.csv'
#       2
# ----> 3 ld=pd.read_csv(file)
#       4
#       5 ld
#
# ...

# %%
file='C:\Users\pc\Documents\R\M4_Diabetes.csv'

ld=pd.read_csv(file)

ld
# Out:
#   File "<ipython-input-4-176bf6a07663>", line 1
#     file='C:\Users\pc\Documents\R\M4_Diabetes.csv'
#         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
file=C'Users\pc\Documents\R\M4_Diabetes.csv'
# Out:
#   File "<ipython-input-5-27ae38d21d75>", line 1
#     file=C'Users\pc\Documents\R\M4_Diabetes.csv'
#                                                ^
# SyntaxError: invalid syntax

# %%
file='C\Users\pc\Documents\R\M4_Diabetes.csv'

ld=pd.read_csv(file)
# Out:
#   File "<ipython-input-6-93dc6cbca0e4>", line 1
#     file='C\Users\pc\Documents\R\M4_Diabetes.csv'
#         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 1-2: truncated \UXXXXXXXX escape

# %%
file='C\Users\pc\Documents\R\M4_Diabetes.csv'

ld=pd.read_csv(file)

ld
# Out:
#   File "<ipython-input-7-018efdd8a549>", line 1
#     file='C\Users\pc\Documents\R\M4_Diabetes.csv'
#         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 1-2: truncated \UXXXXXXXX escape

# %%
file='C:\Users\pc\Downloads\Linear Model Exercise.ipynb'

ld=pd.read_csv(file)

ld
# Out:
#   File "<ipython-input-8-dc0025d896ed>", line 1
#     file='C:\Users\pc\Downloads\Linear Model Exercise.ipynb'
#         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df=pd.read_csv("https://archive.ics.uci.edu/ml/"'machine-learning-databases/iris/iris.data',header=None)
df
# Out:
#        0    1    2    3               4
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# 5    5.4  3.9  1.7  0.4     Iris-setosa
# 6    4.6  3.4  1.4  0.3     Iris-setosa
# 7    5.0  3.4  1.5  0.2     Iris-setosa
# 8    4.4  2.9  1.4  0.2     Iris-setosa
# 9    4.9  3.1  1.5  0.1     Iris-setosa
# 10   5.4  3.7  1.5  0.2     Iris-setosa
# 11   4.8  3.4  1.6  0.2     Iris-setosa
# 12   4.8  3.0  1.4  0.1     Iris-setosa
# 13   4.3  3.0  1.1  0.1     Iris-setosa
# 14   5.8  4.0  1.2  0.2     Iris-setosa
# 15   5.7  4.4  1.5  0.4     Iris-setosa
# 16   5.4  3.9  1.3  0.4     Iris-setosa
# 17   5.1  3.5  1.4  0.3     Iris-setosa
# 18   5.7  3.8  1.7  0.3     Iris-setosa
# 19   5.1  3.8  1.5  0.3     Iris-setosa
# 20   5.4  3.4  1.7  0.2     Iris-setosa
# 21   5.1  3.7  1.5  0.4     Iris-setosa
# ...

# %%
df.dtypes
# Out:
# 0    float64
# 1    float64
# 2    float64
# 3    float64
# 4     object
# dtype: object

# %%
df.heads()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-74a58189be18> in <module>()
# ----> 1 df.heads()
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'heads'

# %%
ld.drop(0,1,2,3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-de2c96f9fd4e> in <module>()
# ----> 1 ld.drop(0,1,2,3)
#
# NameError: name 'ld' is not defined

# %%
df.drop(0,1,2,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-2dcc5b5e3b62> in <module>()
# ----> 1 df.drop(0,1,2,3)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2148         dropped : type of caller
#    2149         """
# -> 2150         inplace = validate_bool_kwarg(inplace, 'inplace')
#    2151         axis = self._get_axis_number(axis)
#    2152         axis_name = self._get_axis_name(axis)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_validators.py in validate_bool_kwarg(value, arg_name)
#     223         raise ValueError('For argument "%s" expected type bool, '
#     224                          'received type %s.' %
# --> 225                          (arg_name, type(value).__name__))
#     226     return value
#
# ValueError: For argument "inplace" expected type bool, received type int.

# %%
df.drop([0,1,2,3],axis=1,inplace=True)

# %%
df
# Out:
#                   4
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# 10      Iris-setosa
# 11      Iris-setosa
# 12      Iris-setosa
# 13      Iris-setosa
# 14      Iris-setosa
# 15      Iris-setosa
# 16      Iris-setosa
# 17      Iris-setosa
# 18      Iris-setosa
# 19      Iris-setosa
# 20      Iris-setosa
# 21      Iris-setosa
# 22      Iris-setosa
# 23      Iris-setosa
# 24      Iris-setosa
# 25      Iris-setosa
# 26      Iris-setosa
# 27      Iris-setosa
# 28      Iris-setosa
# 29      Iris-setosa
# ..              ...
# 120  Iris-virginica
# 121  Iris-virginica
# 122  Iris-virginica
# 123  Iris-virginica
# 124  Iris-virginica
# 125  Iris-virginica
# 126  Iris-virginica
# 127  Iris-virginica
# 128  Iris-virginica
# 129  Iris-virginica
# 130  Iris-virginica
# 131  Iris-virginica
# 132  Iris-virginica
# ...
